# %%
import requests
res = requests.get('https://sc.hkex.com.hk/TuniS/www.hkex.com.hk/chi/csm/DailyStat/data_tab_daily_20210706c.js?_=1627402659123')
text = res.text.split("=")[1]
import json
final_res = eval(text)
with open('trade.json', 'w') as f:
    json.dump(final_res, f)
print(final_res)
# Out:
# [{'id': 0, 'date': '2021-07-06', 'market': 'SSE Northbound', 'tradingDay': 1, 'content': [{'style': 1, 'table': {'classname': 'tradingTable', 'schema': [['Total Turnover', 'Buy Turnover', 'Sell Turnover', 'Total Trade Count', 'Buy Trade Count', 'Sell Trade Count', 'DQB', 'DQB%']], 'tr': [{'td': [['61,143.50']]}, {'td': [['30,950.37']]}, {'td': [['30,193.13']]}, {'td': [['2,616,093']]}, {'td': [['1,248,383']]}, {'td': [['1,367,710']]}, {'td': [['50,071.71']]}, {'td': [['96']]}]}}, {'style': 2, 'table': {'classname': 'top10Table', 'schema': [['Rank', 'Stock Code', 'Stock Name', 'Buy Turnover', 'Sell Turnover', 'Total Turnover']], 'tr': [{'td': [['1', '601318', '中国平安\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000', '995,390,371', '1,245,511,168', '2,240,901,539']]}, {'td': [['2', '601012', '隆基股份\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000', '915,219,071', '942,151,392', '1,857,370,463']]}, {'td': [['3', '600519', '贵州茅台\u3000\u3000\u3000\u3000\u30
# ...
